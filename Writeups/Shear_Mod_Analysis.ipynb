# %% [markdown]
# # Changing Shear Modulus In Basic CitCom_VE Model

# %% [markdown]
# ## Input Changes:
# - Increasing/Decreasing Shear Modulus value (keeping it constant throughout material)
# - Keeping everything in input_VS1 the same

# %% [markdown]
# ## Files:
# * inputSHEAR1: Shear modulus stays at 5e10
# * inputSHEAR2: Shear modulus goes up to 5e11
# * inputSHEAR3: Shear modulus goes up to 5e12
# * inputSHEAR4: Shear modulus goes up to 5e13

# %% [markdown]
# ## Relevant Formulas:
# # $\newline\sigma_{ij}+\frac{\eta}{\mu}\frac{d\sigma_{ij}}{dt}=-p\delta_{ij}+\eta\frac{d\varepsilon_{ij}}{dt}$

# %% [markdown]
# ## Predictions:
# Based on the above formulae I predict that as the shear modulus goes up the the strain will go down since shear modulus and strain are inversely proportional. The opposite will be true when the shear modulus goes down. The above equation can be rewritten to $\;\frac{1}{\eta}(\sigma_{ij}+\frac{\eta}{\mu}\frac{d\sigma_{ij}}{dt}+p\delta_{ij})=\frac{d\varepsilon_{ij}}{dt}\;$ to more clearly see this relationship (where $\mu$ is the shear modulus).

# %% [markdown]
# ## Process:
# In order to see the effects of the strain, I will compare and graph the topographical data at mulitple different times to see the effects of a changed shear modulus.

# %% [markdown]
# ***

# %% [markdown]
# ## Graphing

# %% [markdown]
# ### Topography

# %% [markdown]
# ### Code

# %%
## Imports:
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
topo1_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD1_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo1_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD1_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo1_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD1_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo1_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD1_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])

topo2_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD2_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo2_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD2_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo2_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD2_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo2_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD2_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])

topo3_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD3_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo3_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD3_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo3_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD3_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo3_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD3_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])

topo4_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD4_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo4_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD4_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo4_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD4_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topo4_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\SHEARMOD4_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])




xCor1_30 = topo1_30["xCor"]
zCor1_30 = topo1_30["zCor"]
zPrime1_30 = topo1_30["zPrime"]

xCor1_150 = topo1_150["xCor"]
zCor1_150 = topo1_150["zCor"]
zPrime1_150 = topo1_150["zPrime"]

xCor1_300 = topo1_300["xCor"]
zCor1_300 = topo1_300["zCor"]
zPrime1_300 = topo1_300["zPrime"]

xCor1_400 = topo1_400["xCor"]
zCor1_400 = topo1_400["zCor"]
zPrime1_400 = topo1_400["zPrime"]

xCor2_30 = topo2_30["xCor"]
zCor2_30 = topo2_30["zCor"]
zPrime2_30 = topo2_30["zPrime"]

xCor2_150 = topo2_150["xCor"]
zCor2_150 = topo2_150["zCor"]
zPrime2_150 = topo2_150["zPrime"]

xCor2_300 = topo2_300["xCor"]
zCor2_300 = topo2_300["zCor"]
zPrime2_300 = topo2_300["zPrime"]

xCor2_400 = topo2_400["xCor"]
zCor2_400 = topo2_400["zCor"]
zPrime2_400 = topo2_400["zPrime"]

xCor3_30 = topo3_30["xCor"]
zCor3_30 = topo3_30["zCor"]
zPrime3_30 = topo3_30["zPrime"]

xCor3_150 = topo3_150["xCor"]
zCor3_150 = topo3_150["zCor"]
zPrime3_150 = topo3_150["zPrime"]

xCor3_300 = topo3_300["xCor"]
zCor3_300 = topo3_300["zCor"]
zPrime3_300 = topo3_300["zPrime"]

xCor3_400 = topo3_400["xCor"]
zCor3_400 = topo3_400["zCor"]
zPrime3_400 = topo3_400["zPrime"]

xCor4_30 = topo4_30["xCor"]
zCor4_30 = topo4_30["zCor"]
zPrime4_30 = topo4_30["zPrime"]

xCor4_150 = topo4_150["xCor"]
zCor4_150 = topo4_150["zCor"]
zPrime4_150 = topo4_150["zPrime"]

xCor4_300 = topo4_300["xCor"]
zCor4_300 = topo4_300["zCor"]
zPrime4_300 = topo4_300["zPrime"]

xCor4_400 = topo4_400["xCor"]
zCor4_400 = topo4_400["zCor"]
zPrime4_400 = topo4_400["zPrime"]

# %%
{
    "tags": [
        "hide-input",
    ]
}
plt.figure(figsize=(16,12))

plt.subplot(2,2,1)
plt.plot(xCor1_30,zCor1_30,
        xCor2_30,zCor2_30,
        xCor3_30,zCor3_30,
        xCor4_30,zCor4_30)
plt.title('Timestep: 30')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

plt.subplot(2,2,2)
plt.plot(xCor1_150,zCor1_150,
        xCor2_150,zCor2_150,
        xCor3_150,zCor3_150,
        xCor4_150,zCor4_150)
plt.title('Timestep: 150')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

plt.subplot(2,2,3)
plt.plot(xCor1_300,zCor1_300,
        xCor2_300,zCor2_300,
        xCor3_300,zCor3_300,
        xCor4_300,zCor4_300)
plt.title('Timestep: 300')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

plt.subplot(2,2,4)
plt.plot(xCor1_400,zCor1_400,
        xCor2_400,zCor2_400,
        xCor3_400,zCor3_400,
        xCor4_400,zCor4_400)
plt.title('Timestep: 450')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

# %% [markdown]
# ## Conclusion
#
# According to the graphs, it seems as if my prediction was correct. The lower the shear modulus is, the deeper the displacement is. When the shear modulus is all the way up to 5e13, the displacement wave that it creates has a much smaller amplitude than the material with a shear modulus of 5e10. The Earths mantle is comprised of multiple different materials that all range from around 0.1 GPa to 100 Gpa so therefore averaging the shear modulus to 5e10 and making it constant throughout is a reasonable approximation (in Emma's paper). A more accurate study would include a changing shear modulus throughout the mantle (depending on temperature and density) but due to the complixety of calculating with these changes, it would be more demanding on CITCOMVE and therefore would make studying these changes difficult.

# %% [markdown]
# # Varying Loading Period

# %% [markdown]
# ## Files:
#
# * **PERIOD1:** 320 $\tau_0$
# * **PERIOD2:** 0.3125 $\tau_0$
# * **PERIOD3:** 0.0000763 $\tau_0$

# %% [markdown]
# ## Code:

# %%
time_c01 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\PERIOD1_CSV\\c01.time.csv", usecols = ["timestep","time","tot_diss","tot_elast","tot_elast+diss","tot_work","diss","elastic_enrg","work"])

time_c11 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\PERIOD1_CSV\\c11.time.csv", usecols = ["timestep","time","tot_diss","tot_elast","tot_elast+diss","tot_work","diss","elastic_enrg","work"])

time_c23 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\PERIOD1_CSV\\c23.time.csv", usecols = ["timestep","time","tot_diss","tot_elast","tot_elast+diss","tot_work","diss","elastic_enrg","work"])

timestep_c01 = time_c01["time"]
work_c01 = time_c01["work"]
elastic_c01 = time_c01["elastic_enrg"]
diss_c01 = time_c01["diss"]

timestep_c11 = time_c11["time"]
work_c11 = time_c11["work"]
elastic_c11 = time_c11["elastic_enrg"]
diss_c11 = time_c11["diss"]

timestep_c23 = time_c23["time"]
work_c23 = time_c23["work"]
elastic_c23 = time_c23["elastic_enrg"]
diss_c23 = time_c23["diss"]

# %%
plt.figure(figsize=(25,6))

plt.subplot(1,3,1)
plt.plot(timestep_c01,work_c01, ls=':', label = 'Total Work')
plt.plot(timestep_c01,elastic_c01, ls = '--', label = 'Elastic energy', color = 'k')
plt.plot(timestep_c01,diss_c01, label ='Dissipation', color = 'k')
plt.title('Period 1: 320 $\tau_0$')
plt.xlabel('Time')
plt.ylabel('Energy Flux')
plt.legend()

plt.subplot(1,3,2)
plt.plot(timestep_c11,work_c11, ls=':', label = 'Total Work')
plt.plot(timestep_c11,elastic_c11, ls = '--', label = 'Elastic energy', color = 'k')
plt.plot(timestep_c11,diss_c11, label ='Dissipation', color = 'k')
plt.title('Period 2: 0.3125 $\tau_0$')
plt.xlabel('Time')
plt.ylabel('Energy Flux')
plt.legend()

plt.subplot(1,3,3)
plt.plot(timestep_c23,work_c23, ls=':', label = 'Total Work')
plt.plot(timestep_c23,elastic_c23, ls = '--', label = 'Elastic energy', color = 'k')
plt.plot(timestep_c23,diss_c23, label ='Dissipation', color = 'k')
plt.title('Period 3: 0.0000763 $\tau_0$')
plt.xlabel('Time')
plt.ylabel('Energy Flux')
plt.legend()

# %% [markdown]
# ### Why are these loading periods returning strange outputs?

# %% [markdown]
# c05-c09 are not graphing very well

# %%
time_c05 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\PERIOD1_CSV\\c05.time.csv", usecols = ["timestep","time","tot_diss","tot_elast","tot_elast+diss","tot_work","diss","elastic_enrg","work"])

time_c07 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\PERIOD1_CSV\\c07.time.csv", usecols = ["timestep","time","tot_diss","tot_elast","tot_elast+diss","tot_work","diss","elastic_enrg","work"])

time_c09 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\PERIOD1_CSV\\c09.time.csv", usecols = ["timestep","time","tot_diss","tot_elast","tot_elast+diss","tot_work","diss","elastic_enrg","work"])

timestep_c05 = time_c01["time"]
work_c05 = time_c05["work"]
elastic_c05 = time_c05["elastic_enrg"]
diss_c05 = time_c05["diss"]

timestep_c07 = time_c07["time"]
work_c07 = time_c07["work"]
elastic_c07 = time_c07["elastic_enrg"]
diss_c07 = time_c07["diss"]

timestep_c09 = time_c09["time"]
work_c09 = time_c09["work"]
elastic_c09 = time_c09["elastic_enrg"]
diss_c09 = time_c09["diss"]

# %%
plt.figure(figsize=(25,6))

plt.subplot(1,3,1)
plt.plot(timestep_c05,work_c05, ls=':', label = 'Total Work')
plt.plot(timestep_c05,elastic_c05, ls = '--', label = 'Elastic energy', color = 'k')
plt.plot(timestep_c05,diss_c05, label ='Dissipation', color = 'k')
plt.title('c05')
plt.xlabel('Time')
plt.ylabel('Energy Flux')
plt.legend()

plt.subplot(1,3,2)
plt.plot(timestep_c07,work_c07, ls=':', label = 'Total Work')
plt.plot(timestep_c07,elastic_c07, ls = '--', label = 'Elastic energy', color = 'k')
plt.plot(timestep_c07,diss_c07, label ='Dissipation', color = 'k')
plt.title('c07')
plt.xlabel('Time')
plt.ylabel('Energy Flux')
plt.legend()

plt.subplot(1,3,3)
plt.plot(timestep_c09,work_c09, ls=':', label = 'Total Work')
plt.plot(timestep_c09,elastic_c09, ls = '--', label = 'Elastic energy', color = 'k')
plt.plot(timestep_c09,diss_c09, label ='Dissipation', color = 'k')
plt.title('c09')
plt.xlabel('Time')
plt.ylabel('Energy Flux')
plt.legend()

# %% [markdown]
# # Varying Wavelength (Box length)

# %% [markdown]
# ## Files:
#
# * WAVE1: 1.25d
# * WAVE2: 0.75d
# * WAVE3: 0.25d

# %%
topoW1_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE1_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW1_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE1_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW1_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE1_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW1_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE1_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])

topoW2_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE2_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW2_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE2_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW2_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE2_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW2_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE2_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])

topoW3_30 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE3_CSV\\c01.topo_s_00030.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW3_150 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE3_CSV\\c01.topo_s_00150.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW3_300 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE3_CSV\\c01.topo_s_00300.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])
topoW3_400 = pd.read_csv("C:\\Users\\giorg\\Desktop\\Computer_Science\\Research\\VE_Research\\Data\\WAVE3_CSV\\c01.topo_s_00450.dat.csv", usecols = ["xCor","zCor","zPrime","ignore1","ignore2"])

xCorW1_30 = topoW1_30["xCor"]
zCorW1_30 = topoW1_30["zCor"]

xCorW1_150 = topoW1_150["xCor"]
zCorW1_150 = topoW1_150["zCor"]

xCorW1_300 = topoW1_300["xCor"]
zCorW1_300 = topoW1_300["zCor"]

xCorW1_400 = topoW1_400["xCor"]
zCorW1_400 = topoW1_400["zCor"]

xCorW2_30 = topoW2_30["xCor"]
zCorW2_30 = topoW2_30["zCor"]

xCorW2_150 = topoW2_150["xCor"]
zCorW2_150 = topoW2_150["zCor"]

xCorW2_300 = topoW2_300["xCor"]
zCorW2_300 = topoW2_300["zCor"]

xCorW2_400 = topoW2_400["xCor"]
zCorW2_400 = topoW2_400["zCor"]

xCorW3_30 = topoW3_30["xCor"]
zCorW3_30 = topoW3_30["zCor"]

xCorW3_150 = topoW3_150["xCor"]
zCorW3_150 = topoW3_150["zCor"]

xCorW3_300 = topoW3_300["xCor"]
zCorW3_300 = topoW3_300["zCor"]

xCorW3_400 = topoW3_400["xCor"]
zCorW3_400 = topoW3_400["zCor"]

# %%
plt.figure(figsize=(16,12))

plt.subplot(2,2,1)
plt.plot(xCorW1_30,zCorW1_30,
        xCorW2_30,zCorW2_30,
        xCorW3_30,zCorW3_30)
plt.title('Timestep: 30')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

plt.subplot(2,2,2)
plt.plot(xCorW1_150,zCorW1_150,
        xCorW2_150,zCorW2_150,
        xCorW3_150,zCorW3_150)
plt.title('Timestep: 150')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

plt.subplot(2,2,3)
plt.plot(xCorW1_300,zCorW1_300,
        xCorW2_300,zCorW2_300,
        xCorW3_300,zCorW3_300)
plt.title('Timestep: 300')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])

plt.subplot(2,2,4)
plt.plot(xCorW1_400,zCorW1_400,
        xCorW2_400,zCorW2_400,
        xCorW3_400,zCorW3_400)
plt.title('Timestep: 450')
plt.xlabel('X-Coordinate')
plt.ylabel('Vertical Displacment')
plt.legend(['5e10','5e11','5e12','5e13'])
